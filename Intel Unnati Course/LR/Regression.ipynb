# %%
import pdfplumber
with pdfplumber.open('/content/houseprices.pdf') as pdf:
  # Get the number of pages in the PDF file.
  num_pages = pdf.pages
  # Iterate over the pages and extract the text.
  for page in pdf.pages:
    text = page.extract_text()
    print(text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0da9dca96b30> in <cell line: 1>()
# ----> 1 import pdfplumber
#       2 with pdfplumber.open('/content/houseprices.pdf') as pdf:
#       3   # Get the number of pages in the PDF file.
#       4   num_pages = pdf.pages
#       5   # Iterate over the pages and extract the text.
#
# ModuleNotFoundError: No module named 'pdfplumber'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 53.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 78.6 MB/s eta 0:00:00
# ...

# %%
import pdfplumber
with pdfplumber.open('/content/houseprices.pdf') as pdf:
  # Get the number of pages in the PDF file.
  num_pages = pdf.pages
  # Iterate over the pages and extract the text.
  for page in pdf.pages:
    text = page.extract_text()
    print(text)
# Out:
# area price
# 2600 550000
# 3000 565000
# 3200 610000
# 3600 680000
# 4000 725000
# 2500 520000
# 1900 490000
# 1950 500000
# 1500 450000
# 1602 452100
# 1090 320005
# 1260 352525
# 1120 305256
# 2500 540253
# 2456 524569
# 1963 456286
# 2000 442568
# 3656 650253
# 3560 562520
# 3500 550000

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
data = [
    [2600, 550000],
    [3000, 565000],
    [3200, 610000],
    [3600, 680000],
    [4000, 725000],
    [2500, 520000],
    [1900, 490000],
    [1950, 500000],
    [1500, 450000],
    [1602, 452100],
    [1090, 320005],
    [1260, 352525],
    [1120, 305256],
    [2500, 540253],
    [2456, 524569],
    [1963, 456286],
    [2000, 442568],
    [3656, 650253],
    [3560, 562520],
    [3500, 550000],
]

import pandas as pd
df = pd.DataFrame(data, columns=['area', 'price'])
print(df)
# Out:
#     area   price
# 0   2600  550000
# 1   3000  565000
# 2   3200  610000
# 3   3600  680000
# 4   4000  725000
# 5   2500  520000
# 6   1900  490000
# 7   1950  500000
# 8   1500  450000
# 9   1602  452100
# 10  1090  320005
# 11  1260  352525
# 12  1120  305256
# 13  2500  540253
# 14  2456  524569
# 15  1963  456286
# 16  2000  442568
# 17  3656  650253
# 18  3560  562520
# 19  3500  550000

# %%
df.describe().T
# Out:
#        count       mean            std       min       25%       50%  \
# area    20.0    2447.85     919.234594    1090.0    1825.5    2478.0
# price   20.0  512316.75  110644.206254  305256.0  451575.0  522284.5
#
#             75%       max
# area     3275.0    4000.0
# price  563140.0  725000.0

# %%
df['price'].plot()
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import MaxAbsScaler
maxscaler=MaxAbsScaler().fit(df)
maxscaler_x=maxscaler.transform(df)
maxscaler_df=pd.DataFrame(data=maxscaler_x,columns=['area','price'])
maxscaler_df
# Out:
#        area     price
# 0   0.65000  0.758621
# 1   0.75000  0.779310
# 2   0.80000  0.841379
# 3   0.90000  0.937931
# 4   1.00000  1.000000
# 5   0.62500  0.717241
# 6   0.47500  0.675862
# 7   0.48750  0.689655
# 8   0.37500  0.620690
# 9   0.40050  0.623586
# 10  0.27250  0.441386
# 11  0.31500  0.486241
# 12  0.28000  0.421043
# 13  0.62500  0.745177
# 14  0.61400  0.723543
# 15  0.49075  0.629360
# 16  0.50000  0.610439
# 17  0.91400  0.896901
# 18  0.89000  0.775890
# 19  0.87500  0.758621

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression
X = maxscaler_df['area'].to_numpy().reshape(-1, 1)
y = maxscaler_df['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=2)
model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.predict([[0.421043]])
# Out:
# array([0.58799957])
